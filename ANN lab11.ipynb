# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv("ionosphere.csv",delimiter=",")

# %%
data.head()
# Out:
#    1  0  0.99539  -0.05889  0.85243  0.02306  0.83398  -0.37708      1.1  \
# 0  1  0  1.00000  -0.18829  0.93035 -0.36156 -0.10868  -0.93597  1.00000
# 1  1  0  1.00000  -0.03365  1.00000  0.00485  1.00000  -0.12062  0.88965
# 2  1  0  1.00000  -0.45161  1.00000  1.00000  0.71216  -1.00000  0.00000
# 3  1  0  1.00000  -0.02401  0.94140  0.06531  0.92106  -0.23255  0.77152
# 4  1  0  0.02337  -0.00592 -0.09924 -0.11949 -0.00763  -0.11824  0.14706
#
#    0.03760  ...  -0.51171  0.41078  -0.46168  0.21266  -0.34090  0.42267  \
# 0 -0.04549  ...  -0.26569 -0.20468  -0.18401 -0.19040  -0.11593 -0.16626
# 1  0.01198  ...  -0.40220  0.58984  -0.22145  0.43100  -0.17365  0.60436
# 2  0.00000  ...   0.90695  0.51613   1.00000  1.00000  -0.20099  0.25682
# 3 -0.16399  ...  -0.65158  0.13290  -0.53206  0.02431  -0.62197 -0.05707
# 4  0.06637  ...  -0.01535 -0.03240   0.09223 -0.07859   0.00732  0.00000
#
#    -0.54487  0.18641  -0.45300  g
# 0  -0.06288 -0.13738  -0.02447  b
# 1  -0.24180  0.56045  -0.38238  g
# 2   1.00000 -0.32382   1.00000  b
# 3  -0.59573 -0.04608  -0.65697  g
# 4   0.00000 -0.00039   0.12011  b
#
# [5 rows x 35 columns]

# %%
print(data.isnull().sum())
# Out:
# 1            0
# 0            0
# 0.99539      0
# -0.05889     0
# 0.85243      0
# 0.02306      0
# 0.83398      0
# -0.37708     0
# 1.1          0
# 0.03760      0
# 0.85243.1    0
# -0.17755     0
# 0.59755      0
# -0.44945     0
# 0.60536      0
# -0.38223     0
# 0.84356      0
# -0.38542     0
# 0.58212      0
# -0.32192     0
# 0.56971      0
# -0.29674     0
# 0.36946      0
# -0.47357     0
# 0.56811      0
# -0.51171     0
# 0.41078      0
# -0.46168     0
# 0.21266      0
# -0.34090     0
# 0.42267      0
# -0.54487     0
# 0.18641      0
# -0.45300     0
# g            0
# dtype: int64

# %%
X = data.values[1:,0:34].astype(float)
Y = data.values[1:,34]
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(Y)
Y = encoder.transform(Y)

# %%
model = Sequential()
model.add(Dense(34, input_dim=34 , activation= 'relu' ))
model.add(Dense(1,  activation= 'sigmoid' ))

# %%
epochs = 50
learning_rate = 0.1
decay_rate = learning_rate / epochs
momentum = 0.8
sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
model.compile(loss= 'binary_crossentropy' , optimizer=sgd, metrics=[ 'accuracy' ])
# Out:
# C:\Users\Sri Harshitha\anaconda3\anaconda\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
model.fit(X, Y, validation_split=0.33, epochs=epochs, batch_size=8, verbose=2)
# Out:
# Epoch 1/50
# 30/30 - 1s - loss: 0.5166 - accuracy: 0.7554 - val_loss: 0.2737 - val_accuracy: 0.9655
# Epoch 2/50
# 30/30 - 0s - loss: 0.3201 - accuracy: 0.8798 - val_loss: 0.1559 - val_accuracy: 0.9569
# Epoch 3/50
# 30/30 - 0s - loss: 0.1869 - accuracy: 0.9399 - val_loss: 0.0724 - val_accuracy: 0.9741
# Epoch 4/50
# 30/30 - 0s - loss: 0.1779 - accuracy: 0.9313 - val_loss: 0.1515 - val_accuracy: 0.9483
# Epoch 5/50
# 30/30 - 0s - loss: 0.1649 - accuracy: 0.9442 - val_loss: 0.1408 - val_accuracy: 0.9483
# Epoch 6/50
# 30/30 - 0s - loss: 0.1370 - accuracy: 0.9528 - val_loss: 0.0662 - val_accuracy: 0.9914
# Epoch 7/50
# 30/30 - 0s - loss: 0.2847 - accuracy: 0.8884 - val_loss: 0.1150 - val_accuracy: 0.9828
# Epoch 8/50
# 30/30 - 0s - loss: 0.1365 - accuracy: 0.9571 - val_loss: 0.1092 - val_accuracy: 0.9828
# Epoch 9/50
# 30/30 - 0s - loss: 0.1079 - accuracy: 0.9700 - val_loss: 0.0787 - val_accuracy: 0.9828
# Epoch 10/50
# 30/30 - 0s - loss: 0.1051 - accuracy: 0.9657 - val_loss: 0.0940 - val_accuracy: 0.9828
# Epoch 11/50
# 30/30 - 0s - loss: 0.0990 - accuracy: 0.9657 - val_loss: 0.1154 - val_accuracy: 0.9828
# Epoch 12/50
# 30/30 - 0s - loss: 0.0822 - accuracy: 0.9785 - val_loss: 0.1076 - val_accuracy: 0.9828
# Epoch 13/50
# 30/30 - 0s - loss: 0.0786 - accuracy: 0.9785 - val_loss: 0.1009 - val_accuracy: 0.9914
# Epoch 14/50
# 30/30 - 0s - loss: 0.0697 - accuracy: 0.9785 - val_loss: 0.0801 - val_accuracy: 0.9828
# Epoch 15/50
# 30/30 - 0s - loss: 0.0697 - accuracy: 0.9785 - val_loss: 0.0717 - val_accuracy: 0.9828
# Epoch 16/50
# 30/30 - 0s - loss: 0.0611 - accuracy: 0.9828 - val_loss: 0.2121 - val_accuracy: 0.9224
# Epoch 17/50
# 30/30 - 0s - loss: 0.1176 - accuracy: 0.9485 - val_loss: 0.0643 - val_accuracy: 0.9828
# Epoch 18/50
# 30/30 - 0s - loss: 0.0637 - accuracy: 0.9785 - val_loss: 0.0789 - val_accuracy: 0.9741
# Epoch 19/50
# 30/30 - 0s - loss: 0.0588 - accuracy: 0.9871 - val_loss: 0.0702 - val_accuracy: 0.9828
# Epoch 20/50
# 30/30 - 0s - loss: 0.0551 - accuracy: 0.9828 - val_loss: 0.0738 - val_accuracy: 0.9828
# Epoch 21/50
# 30/30 - 0s - loss: 0.0524 - accuracy: 0.9871 - val_loss: 0.0702 - val_accuracy: 0.9914
# Epoch 22/50
# 30/30 - 0s - loss: 0.0498 - accuracy: 0.9871 - val_loss: 0.0605 - val_accuracy: 0.9828
# Epoch 23/50
# 30/30 - 0s - loss: 0.0476 - accuracy: 0.9871 - val_loss: 0.0563 - val_accuracy: 0.9828
# Epoch 24/50
# 30/30 - 0s - loss: 0.0472 - accuracy: 0.9914 - val_loss: 0.0673 - val_accuracy: 0.9828
# Epoch 25/50
# 30/30 - 0s - loss: 0.0462 - accuracy: 0.9914 - val_loss: 0.0624 - val_accuracy: 0.9828
# Epoch 26/50
# 30/30 - 0s - loss: 0.0453 - accuracy: 0.9914 - val_loss: 0.0862 - val_accuracy: 0.9828
# Epoch 27/50
# 30/30 - 0s - loss: 0.0463 - accuracy: 0.9871 - val_loss: 0.0602 - val_accuracy: 0.9828
# Epoch 28/50
# 30/30 - 0s - loss: 0.0413 - accuracy: 0.9914 - val_loss: 0.0701 - val_accuracy: 0.9741
# Epoch 29/50
# 30/30 - 0s - loss: 0.0401 - accuracy: 0.9914 - val_loss: 0.0607 - val_accuracy: 0.9828
# Epoch 30/50
# 30/30 - 0s - loss: 0.0387 - accuracy: 0.9914 - val_loss: 0.0600 - val_accuracy: 0.9828
# Epoch 31/50
# 30/30 - 0s - loss: 0.0365 - accuracy: 0.9957 - val_loss: 0.0515 - val_accuracy: 0.9828
# Epoch 32/50
# 30/30 - 0s - loss: 0.0384 - accuracy: 0.9957 - val_loss: 0.0634 - val_accuracy: 0.9828
# Epoch 33/50
# 30/30 - 0s - loss: 0.0374 - accuracy: 0.9914 - val_loss: 0.0742 - val_accuracy: 0.9741
# Epoch 34/50
# 30/30 - 0s - loss: 0.0363 - accuracy: 0.9957 - val_loss: 0.0547 - val_accuracy: 0.9828
# Epoch 35/50
# 30/30 - 0s - loss: 0.0356 - accuracy: 0.9914 - val_loss: 0.0679 - val_accuracy: 0.9741
# Epoch 36/50
# 30/30 - 0s - loss: 0.0343 - accuracy: 0.9957 - val_loss: 0.0559 - val_accuracy: 0.9828
# Epoch 37/50
# 30/30 - 0s - loss: 0.0341 - accuracy: 0.9957 - val_loss: 0.0606 - val_accuracy: 0.9828
# Epoch 38/50
# 30/30 - 0s - loss: 0.0352 - accuracy: 0.9914 - val_loss: 0.0650 - val_accuracy: 0.9828
# Epoch 39/50
# 30/30 - 0s - loss: 0.0331 - accuracy: 0.9957 - val_loss: 0.0625 - val_accuracy: 0.9828
# Epoch 40/50
# 30/30 - 0s - loss: 0.0331 - accuracy: 0.9957 - val_loss: 0.0646 - val_accuracy: 0.9741
# Epoch 41/50
# 30/30 - 0s - loss: 0.0324 - accuracy: 0.9957 - val_loss: 0.0601 - val_accuracy: 0.9828
# Epoch 42/50
# 30/30 - 0s - loss: 0.0314 - accuracy: 0.9957 - val_loss: 0.0651 - val_accuracy: 0.9741
# Epoch 43/50
# 30/30 - 0s - loss: 0.0307 - accuracy: 0.9957 - val_loss: 0.0566 - val_accuracy: 0.9828
# Epoch 44/50
# 30/30 - 0s - loss: 0.0322 - accuracy: 0.9957 - val_loss: 0.0566 - val_accuracy: 0.9828
# Epoch 45/50
# 30/30 - 0s - loss: 0.0306 - accuracy: 0.9957 - val_loss: 0.0552 - val_accuracy: 0.9828
# Epoch 46/50
# 30/30 - 0s - loss: 0.0300 - accuracy: 0.9957 - val_loss: 0.0646 - val_accuracy: 0.9741
# Epoch 47/50
# 30/30 - 0s - loss: 0.0301 - accuracy: 0.9957 - val_loss: 0.0672 - val_accuracy: 0.9741
# Epoch 48/50
# 30/30 - 0s - loss: 0.0307 - accuracy: 0.9957 - val_loss: 0.0557 - val_accuracy: 0.9828
# Epoch 49/50
# 30/30 - 0s - loss: 0.0295 - accuracy: 0.9957 - val_loss: 0.0590 - val_accuracy: 0.9828
# Epoch 50/50
# 30/30 - 0s - loss: 0.0292 - accuracy: 0.9957 - val_loss: 0.0561 - val_accuracy: 0.9828

# %%
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 11/11 [==============================] - 0s 0s/step - loss: 0.0370 - accuracy: 0.9914
# accuracy: 99.14%
