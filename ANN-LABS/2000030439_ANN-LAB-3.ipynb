# %% [markdown]
# # Artificial Neural Networks
# # Lab3

# %%
#Implementing hebbian learning rule using python
#Learning Rules 

import math
import numpy as np
def computeNet(input, weights):
        net = 0
        for i in range(len(input)):
                net = net + input[i]*weights[i]
        print("NET:")
        print(net)
        return net

def computeFNetBinary(net):
        f_net = 0
        if(net>0):
                f_net = 1
        if(net<0):
                f_net = -1
        return f_net

def computeFNetCont(net):
        f_net = 0
        f_net = (2/(1+math.exp(-net)))-1
        return f_net

def hebb(f_net):
        return f_net

def perceptron(desired, actual):
    return (desired-actual)

def widrow(desired, actual):
    return (desired-actual)

def adjustWeights(inputs, weights, last, binary, desired, rule):
    c = 1
    if(last):
        print("COMPLETE")
        return
    current_input = inputs[0]
    inputs = inputs[1:]
    if desired :
        current_desired = desired[0]
        desired = desired[1:]
    if len(inputs) == 0:
        last = True
    net = computeNet(current_input, weights)
    if(binary):
        f_net = computeFNetBinary(net)
    else:
        f_net = computeFNetCont(net)
    if rule == "hebb":
        r = hebb(f_net)
    elif rule == "perceptron":
        r = perceptron(current_desired, f_net)
    elif rule == "widrow":
        r = widrow(current_desired, net)
    del_weights = []
    for i in range(len(current_input)):
        x = (c*r)*current_input[i]
        del_weights.append(x)
        weights[i] = x
    print("NEW WEIGHTS:")
    print(weights)
    adjustWeights(inputs, weights, last, binary, desired, rule)

if __name__=="__main__":
    #total_inputs = (int)raw_input("Enter Total Number of Inputs)
    #vector_length = (int)raw_input("Enter Length of vector)
    total_inputs = 3
    vector_length = 4
    #for i in range(vector_length):
    #weight.append(raw_input("Enter Initial Weight:")
    weights = np.array([1.5,-1,1.5,0.5]).transpose()
    inputs = [np.array([1,-2,1.5,0]).transpose(),np.array([1,-0.5,-2,-1.5]).transpose(), np.array([0,1,-1,1.5]).transpose()]
    desired = [1,2,1,-1]
    print("BINARY HEBB!")
    adjustWeights(inputs, [2,-1.5,1.5,0.5], False, True, None, "hebb")
    print("CONTINUOUS HEBB!")
    adjustWeights(inputs, [1.97,-1,1.87,0.5], False, False, None, "hebb")
    print("PERCEPTRON!")
    adjustWeights(inputs, [1.6,-1,-1.5,0.5], False, True, desired, "perceptron")
    print("WIDROW HOFF!")
    adjustWeights(inputs, [-1,-1,-0.5,0.5], False, True, desired, "widrow")
# Out:
# BINARY HEBB!
# NET:
# 7.25
# NEW WEIGHTS:
# [1.0, -2.0, 1.5, 0.0]
# NET:
# -1.0
# NEW WEIGHTS:
# [-1.0, 0.5, 2.0, 1.5]
# NET:
# 0.75
# NEW WEIGHTS:
# [0.0, 1.0, -1.0, 1.5]
# COMPLETE
# CONTINUOUS HEBB!
# NET:
# 6.775
# NEW WEIGHTS:
# [0.997718664218264, -1.995437328436528, 1.496577996327396, 0.0]
# NET:
# -0.9977186642182638
# NEW WEIGHTS:
# [-0.46121960885475044, 0.23060980442737522, 0.9224392177095009, 0.6918294132821257]
# NET:
# 0.34591470664106283
# NEW WEIGHTS:
# [0.0, 0.17125311323362613, -0.17125311323362613, 0.2568796698504392]
# COMPLETE
# PERCEPTRON!
# NET:
# 1.35
# NEW WEIGHTS:
# [0.0, -0.0, 0.0, 0.0]
# NET:
# 0.0
# NEW WEIGHTS:
# [2.0, -1.0, -4.0, -3.0]
# NET:
# -1.5
# NEW WEIGHTS:
# [0.0, 2.0, -2.0, 3.0]
# COMPLETE
# WIDROW HOFF!
# NET:
# 0.25
# NEW WEIGHTS:
# [0.75, -1.5, 1.125, 0.0]
# NET:
# -0.75
# NEW WEIGHTS:
# [2.75, -1.375, -5.5, -4.125]
# NET:
# -2.0625
# NEW WEIGHTS:
# [0.0, 3.0625, -3.0625, 4.59375]
# COMPLETE
